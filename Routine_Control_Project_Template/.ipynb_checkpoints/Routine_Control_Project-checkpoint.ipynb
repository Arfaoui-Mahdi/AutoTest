# %%
import NEW_ext_func_headers
import re
import ConvertAndExtractParams
import AST_Worker
import func_defs_ast_extractor

# %% [markdown]
# ### Preparing the AST Tree for the Routine Control service

# %%
txtTab = AST_Worker.readNclearGIME() # Building the AST into a List form
routineIDs = AST_Worker.extRouIDs(txtTab) # Extracting routine IDs
routineAdds = AST_Worker.routAdds(routineIDs,txtTab) # Extracting each routine Add
globalCodeBlocks = AST_Worker.routCodeBlock(routineAdds, txtTab) # Extracting each routine AST code Block

# %% [markdown]
# ### Extracting Servieces names + codes + params form header files

# %%
# This process will extract the AST of each header file, explore each AST to extract each function call with it's args
# and then for a List containing the path where these functions(services) are defined and name of each service with args


import os
counter = 1
headerS = []
headerIndx = []
FuncDecl = []
count = 0
hCoords = []


funcDefsArgs = []  # This list will hold services indices in this form : [ [service_name1, args + type][service_name2, args + type]...]
        
        
# This two structers were made to track the exchange of data, cause we dispose of multiple header files
# containing different and similar services, and to organize the results we should track each header seperatly
    
directory = r'C:\Users\Mahdi\Desktop\GIT_HUB_Directory_PFE2021\Routine_Control_Project_Template\SW_Test\Include'
for filename in os.listdir(directory): # Iterating the whole "Include" folder
    if re.findall("\Absp", filename) or re.findall("\ALib", filename) : #************ find solution to parse all header FILES**********                                                        
        paath = os.path.join(directory, filename)
        t = NEW_ext_func_headers.ext_func_coords(paath)
        for m in t:
            funcDefsArgs.append(m)

# %%
len(funcDefsArgs)
# Out:
# 268

# %%
funcDefsArgs[200]
# Out:
# ['s32WLin_eInitialisationEvents_Exe',
#  [['Arg Name : Fu16CtrlId',
#    "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#   ['Arg Name : FpfError_Idc',
#    "Arg Type :       PtrDecl: []\n        TypeDecl: FpfError_Idc, []\n          IdentifierType: ['LINErrorHandler']\n"],
#   ['Arg Name : FpfRx_Idc',
#    "Arg Type :       PtrDecl: []\n        TypeDecl: FpfRx_Idc, []\n          IdentifierType: ['LINComHandler']\n"],
#   ['Arg Name : FpfTx_Cfm',
#    "Arg Type :       PtrDecl: []\n        TypeDecl: FpfTx_Cfm, []\n          IdentifierType: ['LINComHandler']\n"]]]

# %%
funcDefsArgs
# Out:
# [['s32WCan_eCheckCtrlPresent_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eConfigBaudRate_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Baudrate',
#     "Arg Type :       TypeDecl: Fu16Baudrate, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eConfigEnhancedBaudRate_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Baudrate',
#     "Arg Type :       TypeDecl: Fu16Baudrate, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16DataBaudrate',
#     "Arg Type :       TypeDecl: Fu16DataBaudrate, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eInitialisationEvents_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ProtoColId',
#     "Arg Type :       TypeDecl: Fu16ProtoColId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : FpfError_Idc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfError_Idc, []\n          IdentifierType: ['CANErrorHandler']\n"],
#    ['Arg Name : FpfRx_Idc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfRx_Idc, []\n          IdentifierType: ['CANMBHandler']\n"],
#    ['Arg Name : FpfTx_Cfm',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfTx_Cfm, []\n          IdentifierType: ['CANMBHandler']\n"]]],
#  ['s32WCan_eGlobalIrq_Set',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Enabled',
#     "Arg Type :       TypeDecl: Fu16Enabled, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eMaskGlobalIrq_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eRestoreGlobalIrq_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eRXMask_Set',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ObjType',
#     "Arg Type :       TypeDecl: Fu16ObjType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu32RxMask',
#     "Arg Type :       TypeDecl: Fu32RxMask, []\n        IdentifierType: ['TU32']\n"]]],
#  ['s32WCan_eRXMask_Get',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ObjType',
#     "Arg Type :       TypeDecl: Fu16ObjType, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eEnableIndividualMaskMode_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16EnableMask',
#     "Arg Type :       TypeDecl: Fu16EnableMask, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eAssignProtocol_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ProtoColId',
#     "Arg Type :       TypeDecl: Fu16ProtoColId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eSetupMB_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu32Ident',
#     "Arg Type :       TypeDecl: Fu32Ident, []\n        IdentifierType: ['TU32']\n"],
#    ['Arg Name : Fu16Type',
#     "Arg Type :       TypeDecl: Fu16Type, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eClearMB_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eSetupMBIrqEnable_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Enabled',
#     "Arg Type :       TypeDecl: Fu16Enabled, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eMBPutData_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Data',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Data, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WCan_eMBGetData_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Data',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Data, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WCan_eWriteMBIdent_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu32Ident',
#     "Arg Type :       TypeDecl: Fu32Ident, []\n        IdentifierType: ['TU32']\n"]]],
#  ['s32WCan_eReadMBIdent_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu32Ident',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu32Ident, []\n          IdentifierType: ['TU32']\n"]]],
#  ['s32WCan_eTxPriorityMode_Set',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8PriorityMode',
#     "Arg Type :       TypeDecl: Fu8PriorityMode, []\n        IdentifierType: ['TU8']\n"]]],
#  ['s32WCan_eMBState_Get',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eMBTx_Req',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eMBTxAbort_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eBusOff_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eBusOn_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eBusStatus_Get',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eSetCanSTB_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Val',
#     "Arg Type :       TypeDecl: Fu16Val, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eCheckCtrlPresent_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eConfigBaudrate_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Baudrate',
#     "Arg Type :       TypeDecl: Fu16Baudrate, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eInitialisationEvents_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : FpfError_Idc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfError_Idc, []\n          IdentifierType: ['LINErrorHandler']\n"],
#    ['Arg Name : FpfRx_Idc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfRx_Idc, []\n          IdentifierType: ['LINComHandler']\n"],
#    ['Arg Name : FpfTx_Cfm',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfTx_Cfm, []\n          IdentifierType: ['LINComHandler']\n"]]],
#  ['s32WLin_eGlobalIrq_Set',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Enabled',
#     "Arg Type :       TypeDecl: Fu16Enabled, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eFrameWrite_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8FrameDID',
#     "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu8DataSize',
#     "Arg Type :       TypeDecl: Fu8DataSize, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fpu8Data',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Data, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WLin_eFrameRead_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8FrameDID',
#     "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fpu8FrameSize',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8FrameSize, []\n          IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fpu8Data',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Data, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WLin_eBusOn_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eBusOff_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eTxReq_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8FrameDID',
#     "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu16LinVersion',
#     "Arg Type :       TypeDecl: Fu16LinVersion, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eRxReq_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8FrameDID',
#     "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu8DataSize',
#     "Arg Type :       TypeDecl: Fu8DataSize, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu16LinVersion',
#     "Arg Type :       TypeDecl: Fu16LinVersion, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCore_eBootCanBaudRate_Get',
#   [['Arg Name : Fpu16NomBaudrate',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16NomBaudrate, []\n          IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu16DataBaudrate',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16DataBaudrate, []\n          IdentifierType: ['TU16']\n"]]],
#  ['u8WCore_eBootSA_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['u8WCore_eBootSAType_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s16WCore_eBootVIN_Get',
#   [['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WCore_eConfigEvt_Exe',
#   [['Arg Name : Fu8NumEvt',
#     "Arg Type :       TypeDecl: Fu8NumEvt, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : FpfCallBack',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfCallBack, []\n          IdentifierType: ['EventHandler']\n"],
#    ['Arg Name : Fu8Mode',
#     "Arg Type :       TypeDecl: Fu8Mode, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu32Delay',
#     "Arg Type :       TypeDecl: Fu32Delay, []\n        IdentifierType: ['TU32']\n"],
#    ['Arg Name : Fu32Offset',
#     "Arg Type :       TypeDecl: Fu32Offset, []\n        IdentifierType: ['TU32']\n"],
#    ['Arg Name : Fu8HiPrio',
#     "Arg Type :       TypeDecl: Fu8HiPrio, []\n        IdentifierType: ['TU8']\n"]]],
#  ['s32WCore_eClearEvt_Exe',
#   [['Arg Name : Fu8NumEvt',
#     "Arg Type :       TypeDecl: Fu8NumEvt, []\n        IdentifierType: ['TU8']\n"]]],
#  ['vWTask_eEnterCritical_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['vWTask_eExitCritical_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['vWCore_eECUReset_Exe',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['vWCore_eBoot_Req',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['s32WCore_eGetWkupCfg_Exe',
#   [['Arg Name : Fpu16WkupCfg',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16WkupCfg, []\n          IdentifierType: ['TU16']\n"]]],
#  ['s32WCore_eSetWkupCfg_Exe',
#   [['Arg Name : Fpu16WkupCfg',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16WkupCfg, []\n          IdentifierType: ['TU16']\n"]]],
#  ['vWCore_eGetLastWkupSrc_Exe',
#   [['Arg Name : Fpu16LastWkupSrc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16LastWkupSrc, []\n          IdentifierType: ['TU16']\n"]]],
#  ['u64WCore_eExecutionTime_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WCore_eCheckRtcPresent_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WCore_eRTCRead_Exe',
#   [['Arg Name : FpstRTCTimeStruct',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCTimeStruct, []\n          IdentifierType: ['TstWCore_eRTCStruct']\n"]]],
#  ['s32WCore_eRTCWrite_Exe',
#   [['Arg Name : FpstRTCTimeStruct',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCTimeStruct, []\n          IdentifierType: ['TstWCore_eRTCStruct']\n"]]],
#  ['s32WCore_eRTCAlarm_Set',
#   [['Arg Name : FpstRTCAlarmStruct',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCAlarmStruct, []\n          IdentifierType: ['TstWCore_eRTCAlarmStruct']\n"]]],
#  ['s32WCore_eRTCAlarm_Get',
#   [['Arg Name : FpstRTCAlarmStruct',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCAlarmStruct, []\n          IdentifierType: ['TstWCore_eRTCAlarmStruct']\n"]]],
#  ['s32WCore_eRTCAlarm_Ack',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['vWCore_eReloadInternal_Exe',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['vWCore_eReloadExternal_Exe',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['vWCore_eShutdown_Exe',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['vWCore_eFS0B_Req',
#   [['Arg Name : Fu8Assert',
#     "Arg Type :       TypeDecl: Fu8Assert, []\n        IdentifierType: ['TU8']\n"]]],
#  ['s32WFiles_eEepSize_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WFiles_eEepPageSize_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WFiles_eEepStatus_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WFiles_eEepBlockingRead_Exe',
#   [['Arg Name : Fu16Address',
#     "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WFiles_eEepRead_Exe',
#   [['Arg Name : Fu16Address',
#     "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WFiles_eEepWrite_Exe',
#   [['Arg Name : Fu16Address',
#     "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WIO_eSetupChannel_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : FpunDesc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpunDesc, []\n          IdentifierType: ['TunWIO_eChannelDesc']\n"]]],
#  ['s32WIO_eResetChannel_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WIO_eQuickGetVal_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WIO_eGetVal_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fps32Data',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fps32Data, []\n          IdentifierType: ['TS32']\n"]]],
#  ['s32WIO_eSetVal_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fs32Val',
#     "Arg Type :       TypeDecl: Fs32Val, []\n        IdentifierType: ['TS32']\n"]]],
#  ['Application_Health_Hook',
#   [['Arg Name : FstCoreDump',
#     "Arg Type :       TypeDecl: FstCoreDump, []\n        IdentifierType: ['TstWHealth_eCoreDump']\n"],
#    ['Arg Name : FunFailureCode',
#     "Arg Type :       TypeDecl: FunFailureCode, []\n        IdentifierType: ['TunWHealth_eFailureCode']\n"]]],
#  ['u32WHealth_eGetResetCause_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['u32WHealth_eGetECUStatus_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['Application_Init_Hook',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['Application_Background_Hook',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['vDCpu_eEnterCritical_Exe',
#   [['Arg Name : FpstContext',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstContext, []\n          IdentifierType: ['TstDCpu_eCriticalContext']\n"]]],
#  ['vDCpu_eExitCritical_Exe',
#   [['Arg Name : FpstContext',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstContext, []\n          IdentifierType: ['TstDCpu_eCriticalContext']\n"]]],
#  ['u16DInl_eRawPinVal_Get',
#   [['Arg Name : Fu16Id',
#     "Arg Type :       TypeDecl: Fu16Id, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32DOutl_ePinVal_Set',
#   [['Arg Name : Fu16Id',
#     "Arg Type :       TypeDecl: Fu16Id, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8Val',
#     "Arg Type :       TypeDecl: Fu8Val, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu16SyncMode',
#     "Arg Type :       TypeDecl: Fu16SyncMode, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32MIO_eSetLock_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8LockVal',
#     "Arg Type :       TypeDecl: Fu8LockVal, []\n        IdentifierType: ['TU8']\n"]]],
#  ['vDCpu_eCacheControl_Exe',
#   [['Arg Name : Fu16Enable',
#     "Arg Type :       TypeDecl: Fu16Enable, []\n        IdentifierType: ['TU16']\n"]]],
#  ['vDCpu_ePrefetchControl_Exe',
#   [['Arg Name : Fu16Enable',
#     "Arg Type :       TypeDecl: Fu16Enable, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32PEep_eStatus_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32PEep_eBlockingRead_Exe',
#   [['Arg Name : Fu16Address',
#     "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32PEep_eRead_Exe',
#   [['Arg Name : Fu16Address',
#     "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32PEep_eWrite_Exe',
#   [['Arg Name : Fu16Address',
#     "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s16PEep_eChipDetection_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['vDAux_eTask_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32DUart_eInit_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32DUart_eConfigBaudrate_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu32Baudrate',
#     "Arg Type :       TypeDecl: Fu32Baudrate, []\n        IdentifierType: ['TU32']\n"]]],
#  ['s32DUart_eInitialisationEvents_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : FpfError_Idc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfError_Idc, []\n          IdentifierType: ['TfDUart_eEvt']\n"],
#    ['Arg Name : FpfRx_Idc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfRx_Idc, []\n          IdentifierType: ['TfDUart_eEvt']\n"],
#    ['Arg Name : FpfTx_Cfm',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfTx_Cfm, []\n          IdentifierType: ['TfDUart_eEvt']\n"]]],
#  ['s32DUart_ePutByte_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8Byte',
#     "Arg Type :       TypeDecl: Fu8Byte, []\n        IdentifierType: ['TU8']\n"]]],
#  ['s32DUart_eGetByte_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Data',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Data, []\n          IdentifierType: ['TU8']\n"]]],
#  ['u16DUart_eGetRxBuffLen_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['u16DUart_eGetTxBuffLen_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32DUart_eResetRxBuffer',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32DUart_eResetTxBuffer',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eCheckCtrlPresent_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eConfigBaudRate_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Baudrate',
#     "Arg Type :       TypeDecl: Fu16Baudrate, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eConfigEnhancedBaudRate_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Baudrate',
#     "Arg Type :       TypeDecl: Fu16Baudrate, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16DataBaudrate',
#     "Arg Type :       TypeDecl: Fu16DataBaudrate, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eInitialisationEvents_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ProtoColId',
#     "Arg Type :       TypeDecl: Fu16ProtoColId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : FpfError_Idc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfError_Idc, []\n          IdentifierType: ['CANErrorHandler']\n"],
#    ['Arg Name : FpfRx_Idc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfRx_Idc, []\n          IdentifierType: ['CANMBHandler']\n"],
#    ['Arg Name : FpfTx_Cfm',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfTx_Cfm, []\n          IdentifierType: ['CANMBHandler']\n"]]],
#  ['s32WCan_eGlobalIrq_Set',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Enabled',
#     "Arg Type :       TypeDecl: Fu16Enabled, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eMaskGlobalIrq_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eRestoreGlobalIrq_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eRXMask_Set',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ObjType',
#     "Arg Type :       TypeDecl: Fu16ObjType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu32RxMask',
#     "Arg Type :       TypeDecl: Fu32RxMask, []\n        IdentifierType: ['TU32']\n"]]],
#  ['s32WCan_eRXMask_Get',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ObjType',
#     "Arg Type :       TypeDecl: Fu16ObjType, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eEnableIndividualMaskMode_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16EnableMask',
#     "Arg Type :       TypeDecl: Fu16EnableMask, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eAssignProtocol_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ProtoColId',
#     "Arg Type :       TypeDecl: Fu16ProtoColId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eSetupMB_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu32Ident',
#     "Arg Type :       TypeDecl: Fu32Ident, []\n        IdentifierType: ['TU32']\n"],
#    ['Arg Name : Fu16Type',
#     "Arg Type :       TypeDecl: Fu16Type, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eClearMB_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eSetupMBIrqEnable_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Enabled',
#     "Arg Type :       TypeDecl: Fu16Enabled, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eMBPutData_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Data',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Data, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WCan_eMBGetData_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Data',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Data, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WCan_eWriteMBIdent_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu32Ident',
#     "Arg Type :       TypeDecl: Fu32Ident, []\n        IdentifierType: ['TU32']\n"]]],
#  ['s32WCan_eReadMBIdent_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu32Ident',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu32Ident, []\n          IdentifierType: ['TU32']\n"]]],
#  ['s32WCan_eTxPriorityMode_Set',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8PriorityMode',
#     "Arg Type :       TypeDecl: Fu8PriorityMode, []\n        IdentifierType: ['TU8']\n"]]],
#  ['s32WCan_eMBState_Get',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eMBTx_Req',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eMBTxAbort_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16MBId',
#     "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eBusOff_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eBusOn_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eBusStatus_Get',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eSetCanSTB_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Val',
#     "Arg Type :       TypeDecl: Fu16Val, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eCheckCtrlPresent_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eConfigBaudrate_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Baudrate',
#     "Arg Type :       TypeDecl: Fu16Baudrate, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eInitialisationEvents_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : FpfError_Idc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfError_Idc, []\n          IdentifierType: ['LINErrorHandler']\n"],
#    ['Arg Name : FpfRx_Idc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfRx_Idc, []\n          IdentifierType: ['LINComHandler']\n"],
#    ['Arg Name : FpfTx_Cfm',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfTx_Cfm, []\n          IdentifierType: ['LINComHandler']\n"]]],
#  ['s32WLin_eGlobalIrq_Set',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Enabled',
#     "Arg Type :       TypeDecl: Fu16Enabled, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eFrameWrite_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8FrameDID',
#     "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu8DataSize',
#     "Arg Type :       TypeDecl: Fu8DataSize, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fpu8Data',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Data, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WLin_eFrameRead_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8FrameDID',
#     "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fpu8FrameSize',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8FrameSize, []\n          IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fpu8Data',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Data, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WLin_eBusOn_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eBusOff_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eTxReq_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8FrameDID',
#     "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu16LinVersion',
#     "Arg Type :       TypeDecl: Fu16LinVersion, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eRxReq_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8FrameDID',
#     "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu8DataSize',
#     "Arg Type :       TypeDecl: Fu8DataSize, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu16LinVersion',
#     "Arg Type :       TypeDecl: Fu16LinVersion, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCore_eBootCanBaudRate_Get',
#   [['Arg Name : Fpu16NomBaudrate',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16NomBaudrate, []\n          IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu16DataBaudrate',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16DataBaudrate, []\n          IdentifierType: ['TU16']\n"]]],
#  ['u8WCore_eBootSA_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['u8WCore_eBootSAType_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s16WCore_eBootVIN_Get',
#   [['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WCore_eConfigEvt_Exe',
#   [['Arg Name : Fu8NumEvt',
#     "Arg Type :       TypeDecl: Fu8NumEvt, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : FpfCallBack',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfCallBack, []\n          IdentifierType: ['EventHandler']\n"],
#    ['Arg Name : Fu8Mode',
#     "Arg Type :       TypeDecl: Fu8Mode, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu32Delay',
#     "Arg Type :       TypeDecl: Fu32Delay, []\n        IdentifierType: ['TU32']\n"],
#    ['Arg Name : Fu32Offset',
#     "Arg Type :       TypeDecl: Fu32Offset, []\n        IdentifierType: ['TU32']\n"],
#    ['Arg Name : Fu8HiPrio',
#     "Arg Type :       TypeDecl: Fu8HiPrio, []\n        IdentifierType: ['TU8']\n"]]],
#  ['s32WCore_eClearEvt_Exe',
#   [['Arg Name : Fu8NumEvt',
#     "Arg Type :       TypeDecl: Fu8NumEvt, []\n        IdentifierType: ['TU8']\n"]]],
#  ['vWTask_eEnterCritical_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['vWTask_eExitCritical_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['vWCore_eECUReset_Exe',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['vWCore_eBoot_Req',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['s32WCore_eGetWkupCfg_Exe',
#   [['Arg Name : Fpu16WkupCfg',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16WkupCfg, []\n          IdentifierType: ['TU16']\n"]]],
#  ['s32WCore_eSetWkupCfg_Exe',
#   [['Arg Name : Fpu16WkupCfg',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16WkupCfg, []\n          IdentifierType: ['TU16']\n"]]],
#  ['vWCore_eGetLastWkupSrc_Exe',
#   [['Arg Name : Fpu16LastWkupSrc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16LastWkupSrc, []\n          IdentifierType: ['TU16']\n"]]],
#  ['u64WCore_eExecutionTime_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WCore_eCheckRtcPresent_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WCore_eRTCRead_Exe',
#   [['Arg Name : FpstRTCTimeStruct',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCTimeStruct, []\n          IdentifierType: ['TstWCore_eRTCStruct']\n"]]],
#  ['s32WCore_eRTCWrite_Exe',
#   [['Arg Name : FpstRTCTimeStruct',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCTimeStruct, []\n          IdentifierType: ['TstWCore_eRTCStruct']\n"]]],
#  ['s32WCore_eRTCAlarm_Set',
#   [['Arg Name : FpstRTCAlarmStruct',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCAlarmStruct, []\n          IdentifierType: ['TstWCore_eRTCAlarmStruct']\n"]]],
#  ['s32WCore_eRTCAlarm_Get',
#   [['Arg Name : FpstRTCAlarmStruct',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCAlarmStruct, []\n          IdentifierType: ['TstWCore_eRTCAlarmStruct']\n"]]],
#  ['s32WCore_eRTCAlarm_Ack',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['vWCore_eReloadInternal_Exe',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['vWCore_eReloadExternal_Exe',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['vWCore_eShutdown_Exe',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['vWCore_eFS0B_Req',
#   [['Arg Name : Fu8Assert',
#     "Arg Type :       TypeDecl: Fu8Assert, []\n        IdentifierType: ['TU8']\n"]]],
#  ['Application_Health_Hook',
#   [['Arg Name : FstCoreDump',
#     "Arg Type :       TypeDecl: FstCoreDump, []\n        IdentifierType: ['TstWHealth_eCoreDump']\n"],
#    ['Arg Name : FunFailureCode',
#     "Arg Type :       TypeDecl: FunFailureCode, []\n        IdentifierType: ['TunWHealth_eFailureCode']\n"]]],
#  ['u32WHealth_eGetResetCause_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['u32WHealth_eGetECUStatus_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WIO_eSetupChannel_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : FpunDesc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpunDesc, []\n          IdentifierType: ['TunWIO_eChannelDesc']\n"]]],
#  ['s32WIO_eResetChannel_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WIO_eQuickGetVal_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WIO_eGetVal_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fps32Data',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fps32Data, []\n          IdentifierType: ['TS32']\n"]]],
#  ['s32WIO_eSetVal_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fs32Val',
#     "Arg Type :       TypeDecl: Fs32Val, []\n        IdentifierType: ['TS32']\n"]]],
#  ['s32WFiles_eEepSize_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WFiles_eEepPageSize_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WFiles_eEepStatus_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WFiles_eEepBlockingRead_Exe',
#   [['Arg Name : Fu16Address',
#     "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WFiles_eEepRead_Exe',
#   [['Arg Name : Fu16Address',
#     "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WFiles_eEepWrite_Exe',
#   [['Arg Name : Fu16Address',
#     "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WCan_eCheckCtrlPresent_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eConfigBaudRate_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Baudrate',
#     "Arg Type :       TypeDecl: Fu16Baudrate, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eConfigEnhancedBaudRate_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Baudrate',
#     "Arg Type :       TypeDecl: Fu16Baudrate, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16DataBaudrate',
#     "Arg Type :       TypeDecl: Fu16DataBaudrate, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eInitialisationEvents_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ProtoColId',
#     "Arg Type :       TypeDecl: Fu16ProtoColId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : FpfError_Idc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfError_Idc, []\n          IdentifierType: ['CANErrorHandler']\n"],
#    ['Arg Name : FpfRx_Idc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfRx_Idc, []\n          IdentifierType: ['CANMBHandler']\n"],
#    ['Arg Name : FpfTx_Cfm',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfTx_Cfm, []\n          IdentifierType: ['CANMBHandler']\n"]]],
#  ['s32WCan_eGlobalIrq_Set',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Enabled',
#     "Arg Type :       TypeDecl: Fu16Enabled, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eMaskGlobalIrq_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eRestoreGlobalIrq_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eRXMask_Set',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ObjType',
#     "Arg Type :       TypeDecl: Fu16ObjType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu32RxMask',
#     "Arg Type :       TypeDecl: Fu32RxMask, []\n        IdentifierType: ['TU32']\n"]]],
#  ['s32WCan_eRXMask_Get',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ObjType',
#     "Arg Type :       TypeDecl: Fu16ObjType, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCan_eEnableIndividualMaskMode_Exe',
#   [['Arg Name : Fu16CtrlId',
# ...
#  ['s32WLin_eBusOn_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eBusOff_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eTxReq_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8FrameDID',
#     "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu16LinVersion',
#     "Arg Type :       TypeDecl: Fu16LinVersion, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WLin_eRxReq_Exe',
#   [['Arg Name : Fu16CtrlId',
#     "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu8FrameDID',
#     "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu8DataSize',
#     "Arg Type :       TypeDecl: Fu8DataSize, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu16LinVersion',
#     "Arg Type :       TypeDecl: Fu16LinVersion, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WCore_eBootCanBaudRate_Get',
#   [['Arg Name : Fpu16NomBaudrate',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16NomBaudrate, []\n          IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu16DataBaudrate',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16DataBaudrate, []\n          IdentifierType: ['TU16']\n"]]],
#  ['u8WCore_eBootSA_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['u8WCore_eBootSAType_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s16WCore_eBootVIN_Get',
#   [['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WCore_eConfigEvt_Exe',
#   [['Arg Name : Fu8NumEvt',
#     "Arg Type :       TypeDecl: Fu8NumEvt, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : FpfCallBack',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpfCallBack, []\n          IdentifierType: ['EventHandler']\n"],
#    ['Arg Name : Fu8Mode',
#     "Arg Type :       TypeDecl: Fu8Mode, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu32Delay',
#     "Arg Type :       TypeDecl: Fu32Delay, []\n        IdentifierType: ['TU32']\n"],
#    ['Arg Name : Fu32Offset',
#     "Arg Type :       TypeDecl: Fu32Offset, []\n        IdentifierType: ['TU32']\n"],
#    ['Arg Name : Fu8HiPrio',
#     "Arg Type :       TypeDecl: Fu8HiPrio, []\n        IdentifierType: ['TU8']\n"]]],
#  ['s32WCore_eClearEvt_Exe',
#   [['Arg Name : Fu8NumEvt',
#     "Arg Type :       TypeDecl: Fu8NumEvt, []\n        IdentifierType: ['TU8']\n"]]],
#  ['vWTask_eEnterCritical_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['vWTask_eExitCritical_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['vWCore_eECUReset_Exe',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['vWCore_eBoot_Req',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['s32WCore_eGetWkupCfg_Exe',
#   [['Arg Name : Fpu16WkupCfg',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16WkupCfg, []\n          IdentifierType: ['TU16']\n"]]],
#  ['s32WCore_eSetWkupCfg_Exe',
#   [['Arg Name : Fpu16WkupCfg',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16WkupCfg, []\n          IdentifierType: ['TU16']\n"]]],
#  ['vWCore_eGetLastWkupSrc_Exe',
#   [['Arg Name : Fpu16LastWkupSrc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16LastWkupSrc, []\n          IdentifierType: ['TU16']\n"]]],
#  ['u64WCore_eExecutionTime_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WCore_eCheckRtcPresent_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WCore_eRTCRead_Exe',
#   [['Arg Name : FpstRTCTimeStruct',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCTimeStruct, []\n          IdentifierType: ['TstWCore_eRTCStruct']\n"]]],
#  ['s32WCore_eRTCWrite_Exe',
#   [['Arg Name : FpstRTCTimeStruct',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCTimeStruct, []\n          IdentifierType: ['TstWCore_eRTCStruct']\n"]]],
#  ['s32WCore_eRTCAlarm_Set',
#   [['Arg Name : FpstRTCAlarmStruct',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCAlarmStruct, []\n          IdentifierType: ['TstWCore_eRTCAlarmStruct']\n"]]],
#  ['s32WCore_eRTCAlarm_Get',
#   [['Arg Name : FpstRTCAlarmStruct',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCAlarmStruct, []\n          IdentifierType: ['TstWCore_eRTCAlarmStruct']\n"]]],
#  ['s32WCore_eRTCAlarm_Ack',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['vWCore_eReloadInternal_Exe',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['vWCore_eReloadExternal_Exe',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['vWCore_eShutdown_Exe',
#   [['Arg Name : Fu32MagicNumber',
#     "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]],
#  ['vWCore_eFS0B_Req',
#   [['Arg Name : Fu8Assert',
#     "Arg Type :       TypeDecl: Fu8Assert, []\n        IdentifierType: ['TU8']\n"]]],
#  ['s32WFiles_eEepSize_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WFiles_eEepPageSize_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WFiles_eEepStatus_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WFiles_eEepBlockingRead_Exe',
#   [['Arg Name : Fu16Address',
#     "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WFiles_eEepRead_Exe',
#   [['Arg Name : Fu16Address',
#     "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WFiles_eEepWrite_Exe',
#   [['Arg Name : Fu16Address',
#     "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16Size',
#     "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fpu8Buffer',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]],
#  ['s32WIO_eSetupChannel_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : FpunDesc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpunDesc, []\n          IdentifierType: ['TunWIO_eChannelDesc']\n"]]],
#  ['s32WIO_eResetChannel_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WIO_eQuickGetVal_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WIO_eGetVal_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fps32Data',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fps32Data, []\n          IdentifierType: ['TS32']\n"]]],
#  ['s32WIO_eSetVal_Exe',
#   [['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fs32Val',
#     "Arg Type :       TypeDecl: Fs32Val, []\n        IdentifierType: ['TS32']\n"]]],
#  ['Application_Health_Hook',
#   [['Arg Name : FstCoreDump',
#     "Arg Type :       TypeDecl: FstCoreDump, []\n        IdentifierType: ['TstWHealth_eCoreDump']\n"],
#    ['Arg Name : FunFailureCode',
#     "Arg Type :       TypeDecl: FunFailureCode, []\n        IdentifierType: ['TunWHealth_eFailureCode']\n"]]],
#  ['u32WHealth_eGetResetCause_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['u32WHealth_eGetECUStatus_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['Application_Init_Hook',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['Application_Background_Hook',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WMSP_eInit_Exe',
#   [['Arg Name : FpunConfiguration',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpunConfiguration, []\n          IdentifierType: ['TstWMSP_eConfig']\n"]]],
#  ['u8WMSP_eMSPState_Get',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['vWMSP_eTask_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WMSP_eAddSlave_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fu8Handle, []\n          IdentifierType: ['TU8']\n"],
#    ['Arg Name : FpunDesc',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpunDesc, []\n          IdentifierType: ['TunWMSP_eDeviceDesc']\n"]]],
#  ['s32WMSP_eSlaveUpdate_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"]]],
#  ['s32WMSP_eSaveConfig_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu32Key',
#     "Arg Type :       TypeDecl: Fu32Key, []\n        IdentifierType: ['TU32']\n"]]],
#  ['s32WMSP_eUnlock_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu32Key',
#     "Arg Type :       TypeDecl: Fu32Key, []\n        IdentifierType: ['TU32']\n"]]],
#  ['s32WMSP_eConnect_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"]]],
#  ['s32WMSP_eStartRemoteIO_Exe',
#   [['Arg Name : Fu8Enable',
#     "Arg Type :       TypeDecl: Fu8Enable, []\n        IdentifierType: ['TU8']\n"]]],
#  ['s32WMSP_eReset_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"]]],
#  ['s32WMSP_eSleep_Exe',
#   [['Arg Name : None',
#     "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]],
#  ['s32WMSP_eGetSlaveStatus_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"]]],
#  ['s32WMSP_eSetupChannel_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : FenIOType',
#     "Arg Type :       TypeDecl: FenIOType, []\n        IdentifierType: ['TeWMSP_eIOType']\n"],
#    ['Arg Name : Fu16RangeSize',
#     "Arg Type :       TypeDecl: Fu16RangeSize, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : FpvStructAddress',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpvStructAddress, []\n          IdentifierType: ['void']\n"],
#    ['Arg Name : Fu16StructSize',
#     "Arg Type :       TypeDecl: Fu16StructSize, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fs32InitialValue',
#     "Arg Type :       TypeDecl: Fs32InitialValue, []\n        IdentifierType: ['TS32']\n"]]],
#  ['s32WMSP_eResetChannel_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : FenIOType',
#     "Arg Type :       TypeDecl: FenIOType, []\n        IdentifierType: ['TeWMSP_eIOType']\n"]]],
#  ['s32WMSP_eQuickGetVal_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"]]],
#  ['s32WMSP_eGetVal_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fps32Data',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fps32Data, []\n          IdentifierType: ['TS32']\n"]]],
#  ['s32WMSP_eSetVal_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fu16IOId',
#     "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu16ParameterType',
#     "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#    ['Arg Name : Fu32Val',
#     "Arg Type :       TypeDecl: Fu32Val, []\n        IdentifierType: ['TU32']\n"]]],
#  ['s32WMSP_eGetSlaveSWPartNumber_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : FpstWVersion_eSWPartNB',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstWVersion_eSWPartNB, []\n          IdentifierType: ['TstWVersion_eSWPartNB']\n"]]],
#  ['s32WMSP_eGetSlaveFactoryData_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : FpstWInfo_eFactoryData',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: FpstWInfo_eFactoryData, []\n          IdentifierType: ['TstWInfo_eFactoryData']\n"]]],
#  ['s32WMSP_eGetSlaveSwVersions_Exe',
#   [['Arg Name : Fu8Handle',
#     "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#    ['Arg Name : Fpst_SlaveSwVersions',
#     "Arg Type :       PtrDecl: []\n        TypeDecl: Fpst_SlaveSwVersions, []\n          IdentifierType: ['TstWCore_eSlaveSwVersions']\n"]]]]

# %%
# Preparing the cfg.h file to extrct routine names
headerCode = ConvertAndExtractParams.convCF(r'C:\Users\Mahdi\Desktop\GIT_HUB_Directory_PFE2021\Routine_Control_Project_Template\SW_Test\Sources\APP\doc_app\doc_app_cfg.h') # Entering the header file to explore it
headerCodeList = ConvertAndExtractParams.cleanL(headerCode) # Convert and Clean the header file List to explore it

# %%
def retSerFunArgs(names): # Function to return service specification from "funcDefsArgs" giving the service name(s)
    res = []
    if names:
        for i in names:
            for j in funcDefsArgs:
                if str(i) == str(j[0]):
                    res.append(j)
                    break
    else :
        return [None]
                
    return res

# %%
def extServNames(A) : 
    names = []
    for i in range(0 , len(A)): # For eeach line in a sub routine AST
        if (len(A[i]) == 2) and ("FuncCall" in A[i][1] ):
            x = A[i+3][1] # the name of the service exist in the third element after this element -- to explore more -- (SO FAR SO GOOOD !!)
            names.append(x) # Extract service names of the sub routine
    return names

# %%
# WOOOOOOOORK HEEERE 



Finalll = []
N = []
for A in globalCodeBlocks: # Assuming that only sub-routines makes function calls, that's how we gonna eliminate 
                          # the non sub-routin caught with their values in the AST (to verify) == VERIFIED !! GOOD TO GOOOO
   
    names = extServNames(A)     
    params = retSerFunArgs(names) 
    #print(A[0][1])
    for j in headerCodeList:
        if A[0][1] in j and re.findall("\A#define", j): # Extract sub routine name from the ID value
            Finalll.append([j, params])

# %%
len(N)
# Out:
# 102

# %%
len(Finalll)
# Out:
# 102

# %%
params = []

for i in names:
    params = retSerFunArgs(i) # Extract params of each service of a specific sub routin

# %%
Finalll
# Out:
# [['#define Du8ADoc_iCanConfigureBaudrate                 0x0000      //CAN API',
#   [['s32WCan_eConfigBaudRate_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16Baudrate',
#       "Arg Type :       TypeDecl: Fu16Baudrate, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanSetAcceptanceMask                 0x0001',
#   [['s32WCan_eBusOff_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#    ['s32WCan_eRXMask_Set',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ObjType',
#       "Arg Type :       TypeDecl: Fu16ObjType, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu32RxMask',
#       "Arg Type :       TypeDecl: Fu32RxMask, []\n        IdentifierType: ['TU32']\n"]]],
#    ['s32WCan_eBusOn_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanGetAcceptanceMask                 0x0002',
#   [['s32WCan_eRXMask_Get',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ObjType',
#       "Arg Type :       TypeDecl: Fu16ObjType, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanConfigureEvents                   0x0003',
#   [['s32WCan_eInitialisationEvents_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ProtoColId',
#       "Arg Type :       TypeDecl: Fu16ProtoColId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : FpfError_Idc',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpfError_Idc, []\n          IdentifierType: ['CANErrorHandler']\n"],
#      ['Arg Name : FpfRx_Idc',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpfRx_Idc, []\n          IdentifierType: ['CANMBHandler']\n"],
#      ['Arg Name : FpfTx_Cfm',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpfTx_Cfm, []\n          IdentifierType: ['CANMBHandler']\n"]]]]],
#  ['#define Du8ADoc_iCanEnableEvents                      0x0004',
#   [['s32WCan_eGlobalIrq_Set',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16Enabled',
#       "Arg Type :       TypeDecl: Fu16Enabled, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanSetBusOn                          0x0005',
#   [['s32WCan_eBusOn_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanSetBusOff                         0x0006',
#   [['s32WCan_eBusOff_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanGetStatus                         0x0007',
#   [['s32WCan_eBusStatus_Get',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanConfigureMB                       0x0008',
#   [['s32WCan_eBusOff_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#    ['s32WCan_eSetupMB_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16MBId',
#       "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu32Ident',
#       "Arg Type :       TypeDecl: Fu32Ident, []\n        IdentifierType: ['TU32']\n"],
#      ['Arg Name : Fu16Type',
#       "Arg Type :       TypeDecl: Fu16Type, []\n        IdentifierType: ['TU16']\n"]]],
#    ['s32WCan_eBusOn_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanClearMB                           0x0009',
#   [['s32WCan_eClearMB_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16MBId',
#       "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanAssignProtocolMB                  0x000A',
#   [['s32WCan_eAssignProtocol_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16MBId',
#       "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ProtoColId',
#       "Arg Type :       TypeDecl: Fu16ProtoColId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanEnableMBEvents                    0x000B',
#   [['s32WCan_eSetupMBIrqEnable_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16MBId',
#       "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16Enabled',
#       "Arg Type :       TypeDecl: Fu16Enabled, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanWriteMBData                       0x000C',
#   [['s32WCan_eMBPutData_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16MBId',
#       "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16Size',
#       "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fpu8Data',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Data, []\n          IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iCanReadMBStatus                      0x000D',
#   [['s32WCan_eMBState_Get',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16MBId',
#       "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanReadMBIdent                       0x000E',
#   [['s32WCan_eReadMBIdent_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16MBId',
#       "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fpu32Ident',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu32Ident, []\n          IdentifierType: ['TU32']\n"]]]]],
#  ['#define Du8ADoc_iCanReadMBData                        0x000F',
#   [['s32WCan_eMBGetData_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16MBId',
#       "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fpu8Data',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Data, []\n          IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iCanRequestMBTransmission             0x0010',
#   [['s32WCan_eMBTx_Req',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16MBId',
#       "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanAbortMBTransmission               0x0011',
#   [['s32WCan_eMBTxAbort_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16MBId',
#       "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanWriteMBIdent                      0x0012',
#   [['s32WCan_eWriteMBIdent_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16MBId',
#       "Arg Type :       TypeDecl: Fu16MBId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu32Ident',
#       "Arg Type :       TypeDecl: Fu32Ident, []\n        IdentifierType: ['TU32']\n"]]]]],
#  ['#define Du8ADoc_iCanCheckPresent                      0x0013',
#   [['s32WCan_eCheckCtrlPresent_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanMaskEvents                        0x0014',
#   [['s32WCan_eMaskGlobalIrq_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanRestoreEvents                     0x0015',
#   [['s32WCan_eRestoreGlobalIrq_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanEnableAcceptanceMask              0x0017',
#   [['s32WCan_eEnableIndividualMaskMode_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16EnableMask',
#       "Arg Type :       TypeDecl: Fu16EnableMask, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanSetSTB                            0x0018',
#   [['s32WCan_eSetCanSTB_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16Val',
#       "Arg Type :       TypeDecl: Fu16Val, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanConfigureEnhancedBaudrate         0x0019',
#   [['s32WCan_eConfigEnhancedBaudRate_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16Baudrate',
#       "Arg Type :       TypeDecl: Fu16Baudrate, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16DataBaudrate',
#       "Arg Type :       TypeDecl: Fu16DataBaudrate, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCanTxPriorityModeSet                 0x0016',
#   [['s32WCan_eTxPriorityMode_Set',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu8PriorityMode',
#       "Arg Type :       TypeDecl: Fu8PriorityMode, []\n        IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iLinConfigBaudrate                    0x0020      //LIN API',
#   [['s32WLin_eConfigBaudrate_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16Baudrate',
#       "Arg Type :       TypeDecl: Fu16Baudrate, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iLinCheckCtrlPresent                  0x0029',
#   [['s32WLin_eCheckCtrlPresent_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iLinConfigureEvents                   0x0021',
#   [['s32WLin_eInitialisationEvents_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : FpfError_Idc',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpfError_Idc, []\n          IdentifierType: ['LINErrorHandler']\n"],
#      ['Arg Name : FpfRx_Idc',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpfRx_Idc, []\n          IdentifierType: ['LINComHandler']\n"],
#      ['Arg Name : FpfTx_Cfm',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpfTx_Cfm, []\n          IdentifierType: ['LINComHandler']\n"]]]]],
#  ['#define Du8ADoc_iLinGlobalIrqSet                      0x0022',
#   [['s32WLin_eGlobalIrq_Set',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16Enabled',
#       "Arg Type :       TypeDecl: Fu16Enabled, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iLinBusOn                             0x0023',
#   [['s32WLin_eBusOn_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iLinBusOff                            0x0024',
#   [['s32WLin_eBusOff_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iLinFrameWrite                        0x0025',
#   [['s32WLin_eFrameWrite_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu8FrameDID',
#       "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fu8DataSize',
#       "Arg Type :       TypeDecl: Fu8DataSize, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fpu8Data',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Data, []\n          IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iLinFrameRead                         0x0026',
#   [['s32WLin_eFrameRead_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu8FrameDID',
#       "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fpu8FrameSize',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8FrameSize, []\n          IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fpu8Data',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Data, []\n          IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iLinTxReq                             0x0027',
#   [['s32WLin_eTxReq_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu8FrameDID',
#       "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fu16LinVersion',
#       "Arg Type :       TypeDecl: Fu16LinVersion, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iLinRxReq                             0x0028',
#   [['s32WLin_eRxReq_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu8FrameDID',
#       "Arg Type :       TypeDecl: Fu8FrameDID, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fu8DataSize',
#       "Arg Type :       TypeDecl: Fu8DataSize, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fu16LinVersion',
#       "Arg Type :       TypeDecl: Fu16LinVersion, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCoreBootSAGet                        0x0104',
#   [['u8WCore_eBootSA_Get',
#     [['Arg Name : None',
#       "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]]]],
#  ['#define Du8ADoc_iCoreBootCANBaudrateGet               0x0105',
#   [['s32WCore_eBootCanBaudRate_Get',
#     [['Arg Name : Fpu16NomBaudrate',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16NomBaudrate, []\n          IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fpu16DataBaudrate',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16DataBaudrate, []\n          IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iCoreResetRequest                     0x0108',
#   [['vWCore_eECUReset_Exe',
#     [['Arg Name : Fu32MagicNumber',
#       "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]]]],
#  ['#define Du8ADoc_iCoreBootReq                          0x0113',
#   [['vWCore_eBoot_Req',
#     [['Arg Name : Fu32MagicNumber',
#       "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]]]],
#  ['#define Du8ADoc_iCoreGetCPUExecTime                   0x0109',
#   [['u64WCore_eExecutionTime_Exe',
#     [['Arg Name : None',
#       "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]]]],
#  ['#define Du8ADoc_iCoreInternalWatchdogReload           0x010D',
#   [['vWCore_eReloadInternal_Exe',
#     [['Arg Name : Fu32MagicNumber',
#       "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]]]],
#  ['#define Du8ADoc_iCoreExternalWatchdogReload           0x010E',
#   [['vWCore_eReloadExternal_Exe',
#     [['Arg Name : Fu32MagicNumber',
#       "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]]]],
#  ['#define Du8ADoc_iCoreBoardShutDownRequest             0x0110',
#   [['vWCore_eShutdown_Exe',
#     [['Arg Name : Fu32MagicNumber',
#       "Arg Type :       TypeDecl: Fu32MagicNumber, []\n        IdentifierType: ['TU32']\n"]]]]],
#  ['#define Du8ADoc_iCoreBootVINGet                       0x0112',
#   [['s16WCore_eBootVIN_Get',
#     [['Arg Name : Fpu8Buffer',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iCoreCheckRTCPresent                  0x010A',
#   [['s32WCore_eCheckRtcPresent_Exe',
#     [['Arg Name : None',
#       "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]]]],
#  ['#define Du8ADoc_iCoreRTCRead                          0x010B',
#   [['s32WCore_eRTCRead_Exe',
#     [['Arg Name : FpstRTCTimeStruct',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCTimeStruct, []\n          IdentifierType: ['TstWCore_eRTCStruct']\n"]]]]],
#  ['#define Du8ADoc_iCoreRTCWrite                         0x010C',
#   [['s32WCore_eRTCWrite_Exe',
#     [['Arg Name : FpstRTCTimeStruct',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCTimeStruct, []\n          IdentifierType: ['TstWCore_eRTCStruct']\n"]]]]],
#  ['#define Du8ADoc_iCoreTaskSetup                        0x0106',
#   [['s32WCore_eConfigEvt_Exe',
#     [['Arg Name : Fu8NumEvt',
#       "Arg Type :       TypeDecl: Fu8NumEvt, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : FpfCallBack',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpfCallBack, []\n          IdentifierType: ['EventHandler']\n"],
#      ['Arg Name : Fu8Mode',
#       "Arg Type :       TypeDecl: Fu8Mode, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fu32Delay',
#       "Arg Type :       TypeDecl: Fu32Delay, []\n        IdentifierType: ['TU32']\n"],
#      ['Arg Name : Fu32Offset',
#       "Arg Type :       TypeDecl: Fu32Offset, []\n        IdentifierType: ['TU32']\n"],
#      ['Arg Name : Fu8HiPrio',
#       "Arg Type :       TypeDecl: Fu8HiPrio, []\n        IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iCoreTaskClear                        0x0107',
#   [['s32WCore_eClearEvt_Exe',
#     [['Arg Name : Fu8NumEvt',
#       "Arg Type :       TypeDecl: Fu8NumEvt, []\n        IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iWkupSrcGet                           0x0101',
#   [['s32WCore_eGetWkupCfg_Exe',
#     [['Arg Name : Fpu16WkupCfg',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16WkupCfg, []\n          IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iWkupSrcSet                           0x0102',
#   [['s32WCore_eSetWkupCfg_Exe',
#     [['Arg Name : Fpu16WkupCfg',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16WkupCfg, []\n          IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iLastWkupSrcGet                       0x0103',
#   [['vWCore_eGetLastWkupSrc_Exe',
#     [['Arg Name : Fpu16LastWkupSrc',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu16LastWkupSrc, []\n          IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_icoreRTCAlarmSet                      0x0114',
#   [['s32WCore_eRTCAlarm_Set',
#     [['Arg Name : FpstRTCAlarmStruct',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCAlarmStruct, []\n          IdentifierType: ['TstWCore_eRTCAlarmStruct']\n"]]]]],
#  ['#define Du8ADoc_icoreRTCAlarmGet                      0x0115',
#   [['s32WCore_eRTCAlarm_Get',
#     [['Arg Name : FpstRTCAlarmStruct',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpstRTCAlarmStruct, []\n          IdentifierType: ['TstWCore_eRTCAlarmStruct']\n"]]]]],
#  ['#define Du8ADoc_icoreRTCAlarmAck                      0x0116',
#   [['s32WCore_eRTCAlarm_Ack',
#     [['Arg Name : None',
#       "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]]]],
#  ['#define Du8ADoc_icoreBootSATypeGet                    0x0117',
#   [['u8WCore_eBootSAType_Get',
#     [['Arg Name : None',
#       "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]]]],
#  ['#define Du8ADoc_icoreFS0BReq                          0x0118',
#   [['vWCore_eFS0B_Req',
#     [['Arg Name : Fu8Assert',
#       "Arg Type :       TypeDecl: Fu8Assert, []\n        IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iEepGetStatus                         0x0200',
#   [['s32WFiles_eEepStatus_Get',
#     [['Arg Name : None',
#       "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]]]],
#  ['#define Du8ADoc_iEepReadData                          0x0201',
#   [['s32WFiles_eEepRead_Exe',
#     [['Arg Name : Fu16Address',
#       "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16Size',
#       "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fpu8Buffer',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iEepWriteData                         0x0202',
#   [['s32WFiles_eEepWrite_Exe',
#     [['Arg Name : Fu16Address',
#       "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16Size',
#       "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fpu8Buffer',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iEepSizeGet                           0x0203',
#   [['s32WFiles_eEepSize_Get',
#     [['Arg Name : None',
#       "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]]]],
#  ['#define Du8ADoc_iEepPageSizeGet                       0x0204',
#   [['s32WFiles_eEepPageSize_Get',
#     [['Arg Name : None',
#       "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]]]],
#  ['#define Du8ADoc_iEepBlockingReadData                  0x0205',
#   [['s32WFiles_eEepBlockingRead_Exe',
#     [['Arg Name : Fu16Address',
#       "Arg Type :       TypeDecl: Fu16Address, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16Size',
#       "Arg Type :       TypeDecl: Fu16Size, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fpu8Buffer',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpu8Buffer, []\n          IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iEepGetTmpBuffer                      0x0206', [None]],
#  ['#define Du8ADoc_iIOConfigureChannel                   0x0300',
#   [['s32WIO_eSetupChannel_Exe',
#     [['Arg Name : Fu16IOId',
#       "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ParameterType',
#       "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : FpunDesc',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpunDesc, []\n          IdentifierType: ['TunWIO_eChannelDesc']\n"]]]]],
#  ['#define Du8ADoc_iIOReadDataWith_Error                 0x0301',
#   [['s32WIO_eGetVal_Exe',
#     [['Arg Name : Fu16IOId',
#       "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ParameterType',
#       "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fps32Data',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fps32Data, []\n          IdentifierType: ['TS32']\n"]]]]],
#  ['#define Du8ADoc_iIOReadData                           0x0302',
#   [['s32WIO_eQuickGetVal_Exe',
#     [['Arg Name : Fu16IOId',
#       "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ParameterType',
#       "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iIOClearChannel                       0x0303',
#   [['s32WIO_eResetChannel_Exe',
#     [['Arg Name : Fu16IOId',
#       "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ParameterType',
#       "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iIOSetVal                             0x0304',
#   [['s32WIO_eSetVal_Exe',
#     [['Arg Name : Fu16IOId',
#       "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ParameterType',
#       "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fs32Val',
#       "Arg Type :       TypeDecl: Fs32Val, []\n        IdentifierType: ['TS32']\n"]]]]],
#  ['#define Du8ADoc_iIOInitOuptput                        0x0305',
#   [['s32WIO_eSetupChannel_Exe',
#     [['Arg Name : Fu16IOId',
#       "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ParameterType',
#       "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : FpunDesc',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpunDesc, []\n          IdentifierType: ['TunWIO_eChannelDesc']\n"]]]]],
#  ['#define Du8ADoc_iIOfastSetOutput                      0x0306',
#   [['s32WIO_eSetVal_Exe',
#     [['Arg Name : Fu16IOId',
#       "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ParameterType',
#       "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fs32Val',
#       "Arg Type :       TypeDecl: Fs32Val, []\n        IdentifierType: ['TS32']\n"]]],
#    ['s32WIO_eSetVal_Exe',
#     [['Arg Name : Fu16IOId',
#       "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ParameterType',
#       "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fs32Val',
#       "Arg Type :       TypeDecl: Fs32Val, []\n        IdentifierType: ['TS32']\n"]]]]],
#  ['#define Du8ADoc_iMSPConfigure                         0x0400',
#   [['s32WCan_eBusOff_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"]]],
#    ['s32WCan_eConfigEnhancedBaudRate_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16Baudrate',
#       "Arg Type :       TypeDecl: Fu16Baudrate, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16DataBaudrate',
#       "Arg Type :       TypeDecl: Fu16DataBaudrate, []\n        IdentifierType: ['TU16']\n"]]],
#    ['s32WCan_eEnableIndividualMaskMode_Exe',
#     [['Arg Name : Fu16CtrlId',
#       "Arg Type :       TypeDecl: Fu16CtrlId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16EnableMask',
#       "Arg Type :       TypeDecl: Fu16EnableMask, []\n        IdentifierType: ['TU16']\n"]]],
#    ['s32WMSP_eInit_Exe',
#     [['Arg Name : FpunConfiguration',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpunConfiguration, []\n          IdentifierType: ['TstWMSP_eConfig']\n"]]]]],
#  ['#define Du8ADoc_iMSPStateRead                         0x0401',
#   [['u8WMSP_eMSPState_Get',
#     [['Arg Name : None',
#       "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]]]],
#  ['#define Du8ADoc_iMSPAddSlave                          0x0402',
#   [['s32WMSP_eAddSlave_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fu8Handle, []\n          IdentifierType: ['TU8']\n"],
#      ['Arg Name : FpunDesc',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpunDesc, []\n          IdentifierType: ['TunWMSP_eDeviceDesc']\n"]]]]],
#  ['#define Du8ADoc_iMSPSlaveUpdate                       0x0403',
#   [['s32WMSP_eSlaveUpdate_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iMSPSaveConfig                        0x0404',
#   [['s32WMSP_eSaveConfig_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fu32Key',
#       "Arg Type :       TypeDecl: Fu32Key, []\n        IdentifierType: ['TU32']\n"]]]]],
#  ['#define Du8ADoc_iMSPeUnlockService                    0x0405',
#   [['s32WMSP_eUnlock_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fu32Key',
#       "Arg Type :       TypeDecl: Fu32Key, []\n        IdentifierType: ['TU32']\n"]]]]],
#  ['#define Du8ADoc_iMSPSConnectSlave                     0x0406',
#   [['s32WMSP_eConnect_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iMSPStartRemoteIO                     0x0407',
#   [['s32WMSP_eStartRemoteIO_Exe',
#     [['Arg Name : Fu8Enable',
#       "Arg Type :       TypeDecl: Fu8Enable, []\n        IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iMSPResetSlave                        0x0408',
#   [['s32WMSP_eReset_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iMSPSleepSlaves                       0x0409',
#   [['s32WMSP_eSleep_Exe',
#     [['Arg Name : None',
#       "Arg Type :       TypeDecl: None, []\n        IdentifierType: ['void']\n"]]]]],
#  ['#define Du8ADoc_iMSPGetSlaveStatus                    0x040A',
#   [['s32WMSP_eGetSlaveStatus_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iMSPIOConfigureChannel                0x040B',
#   [['s32WMSP_eSetupChannel_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fu16IOId',
#       "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ParameterType',
#       "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : FenIOType',
#       "Arg Type :       TypeDecl: FenIOType, []\n        IdentifierType: ['TeWMSP_eIOType']\n"],
#      ['Arg Name : Fu16RangeSize',
#       "Arg Type :       TypeDecl: Fu16RangeSize, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : FpvStructAddress',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpvStructAddress, []\n          IdentifierType: ['void']\n"],
#      ['Arg Name : Fu16StructSize',
#       "Arg Type :       TypeDecl: Fu16StructSize, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fs32InitialValue',
#       "Arg Type :       TypeDecl: Fs32InitialValue, []\n        IdentifierType: ['TS32']\n"]]]]],
#  ['#define Du8ADoc_iMSPIOReadDataWith_Error              0x040E',
#   [['s32WMSP_eGetVal_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fu16IOId',
#       "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ParameterType',
#       "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fps32Data',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fps32Data, []\n          IdentifierType: ['TS32']\n"]]]]],
#  ['#define Du8ADoc_iMSPIOReadData                        0x040D',
#   [['s32WMSP_eQuickGetVal_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fu16IOId',
#       "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ParameterType',
#       "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"]]]]],
#  ['#define Du8ADoc_iMSPIOClearChannel                    0x040C',
#   [['s32WMSP_eResetChannel_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fu16IOId',
#       "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ParameterType',
#       "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : FenIOType',
#       "Arg Type :       TypeDecl: FenIOType, []\n        IdentifierType: ['TeWMSP_eIOType']\n"]]]]],
#  ['#define Du8ADoc_iMSPIOWriteData                       0x040F',
#   [['s32WMSP_eSetVal_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fu16IOId',
#       "Arg Type :       TypeDecl: Fu16IOId, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu16ParameterType',
#       "Arg Type :       TypeDecl: Fu16ParameterType, []\n        IdentifierType: ['TU16']\n"],
#      ['Arg Name : Fu32Val',
#       "Arg Type :       TypeDecl: Fu32Val, []\n        IdentifierType: ['TU32']\n"]]]]],
#  ['#define Du8ADoc_iMSPSlaveFactoryData                  0x0410',
#   [['s32WMSP_eGetSlaveFactoryData_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : FpstWInfo_eFactoryData',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpstWInfo_eFactoryData, []\n          IdentifierType: ['TstWInfo_eFactoryData']\n"]]]]],
#  ['#define Du8ADoc_iMSPSWPartNumber                      0x0411',
#   [['s32WMSP_eGetSlaveSWPartNumber_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : FpstWVersion_eSWPartNB',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpstWVersion_eSWPartNB, []\n          IdentifierType: ['TstWVersion_eSWPartNB']\n"]]]]],
#  ['#define Du8ADoc_iMSPSlaveSwVersions                   0x0412',
#   [['s32WMSP_eGetSlaveSwVersions_Exe',
#     [['Arg Name : Fu8Handle',
#       "Arg Type :       TypeDecl: Fu8Handle, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fpst_SlaveSwVersions',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: Fpst_SlaveSwVersions, []\n          IdentifierType: ['TstWCore_eSlaveSwVersions']\n"]]]]],
#  ['#define Du8ADoc_iMSPTaskActivation                    0x0413',
#   [['s32WCore_eConfigEvt_Exe',
#     [['Arg Name : Fu8NumEvt',
#       "Arg Type :       TypeDecl: Fu8NumEvt, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : FpfCallBack',
#       "Arg Type :       PtrDecl: []\n        TypeDecl: FpfCallBack, []\n          IdentifierType: ['EventHandler']\n"],
#      ['Arg Name : Fu8Mode',
#       "Arg Type :       TypeDecl: Fu8Mode, []\n        IdentifierType: ['TU8']\n"],
#      ['Arg Name : Fu32Delay',
#       "Arg Type :       TypeDecl: Fu32Delay, []\n        IdentifierType: ['TU32']\n"],
#      ['Arg Name : Fu32Offset',
#       "Arg Type :       TypeDecl: Fu32Offset, []\n        IdentifierType: ['TU32']\n"],
#      ['Arg Name : Fu8HiPrio',
#       "Arg Type :       TypeDecl: Fu8HiPrio, []\n        IdentifierType: ['TU8']\n"]]]]],
#  ['#define Du8ADoc_iBOOTSecKey_Get                       0x0500', []],
#  ['#define Du8ADoc_iBOOTSecAccess_Calc                   0x0501', []],
#  ['#define Du8ADoc_iBOOTSAGet_Exe                        0x0502', []],
#  ['#define Du8ADoc_iBOOTNameGet_Exe                      0x0503', []],
#  ['#define Du8ADoc_iBOOTHWIDGet_Exe                      0x0504', []],
#  ['#define Du8ADoc_iBOOTSATypeGet_Exe                    0x0505', []],
#  ['#define Du8ADoc_iBOOTBaudrateGet_Exe                  0x0506', []],
#  ['#define Du8ADoc_iBOOTVINGet_Exe                       0x0507', []],
#  ['#define Du8ADoc_iBOOTEthIfeGet_Exe                    0x0508', []],
#  ['#define Du8ADoc_iBOOTVMECUHNGet_Exe                   0x0509', []]]

# %%
len(Finalll)
# Out:
# 102

# %%
# Out:
# 102
